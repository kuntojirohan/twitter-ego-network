# %% [markdown]
# When it comes to consuming real-time content, Twitter is the place to be; Be it sending out 'Tweets' real-time, or discovering latest online 'Trends' anywhere, or ability to begin a 'conversation' with anyone, Twitter does it all. In fact, Twitter Management wrote this in their [letter to shareholders][1] last year.
# [1]: http://files.shareholder.com/downloads/AMDA-2F526X/106725176x0x874459/8A4D1A1D-D184-4AFE-9AC1-F880C5EA06F1/Q415_Shareholder_Letter.pdf
#
# > _We’re focused now on what Twitter does best: live. Twitter is live: live commentary, live connections, live conversations. Whether it’s breaking news, entertainment, sports, or everyday topics, hearing about and watching a live event unfold is the fastest way to understand the power of Twitter._
#
# > _Twitter has always been considered a “second screen” for what’s happening in the world and we believe we can become the first screen for everything that’s happening now. And by doing so, we believe we can build the planet’s largest daily connected audience. A connected audience is one that watches together, and can talk with one another in real-time. It’s what Twitter has provided for close to 10 years, and it’s what we will continue to drive in the future_

# %% [markdown]
# Embedded in a Twitter User's Social-graph* is a wealth of information on User's likes and interests. Unlike Facebook or LinkedIn, the magic of Twitter is in its 'Follow' structure - where any can follow any without they knowing each other. This directed social-graph, when methodologically summarized, can reveal interesting information on the most influential/central friends in the network and also help personalize/enrich one's Twitter experience by unearthing implicit-clusters in the network.
#
# _*Social-graph: [User, 1st degree Connections, and the links between]_

# %% [markdown]
# In this notebook, we'll look into these:
# 1. Extract the ego-network of 'self' using Twitter API
# + Identify the influential nodes using 'Page Rank' formulation
# + Identify implicit clusters formed
# + Recommend new friends to follow on the basis of cluster of interest

# %% [markdown]
# Note: This study is limited to  Ego network: the focal node ("ego": here the self-node) and the nodes to whom ego is directly connected to ("alters") plus the ties, if any, among the alters.

# %% [markdown]
# ## 1. Extract social-graph strucutre using Twitter API

# %%
from collections import Counter, defaultdict
from datetime import datetime
from sklearn.decomposition import PCA

import csv
import matplotlib.pyplot as plt
import numpy as np
import os.path
import pandas as pd
import re
import seaborn as sns;  sns.set()
import time
import twitter

% matplotlib inline
plt.rcParams['figure.figsize'] = (10,7)

import warnings
warnings.filterwarnings("ignore")
#print twitter.__path__  

import random
random.seed(1000)
# Out:
# UsageError: Line magic function `%` not found.

# %%
# Pandas data-frame print formatting
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
self_screen_name = 'RohanKuntoji'            # Self

# Keep appending data
fof_filename     = "edges.csv"          # 'Alters' and their Source->Sink Edges. 
cache_filename   = "cache.csv"          # local cache of (TwitterId, FullName, UserName)

# One-time-use files
binaryMap_filename = "binaryMap.csv"   # Directed Graph. Adjacencies as 0/1.RowFollowCol
cluster_filename   = "results.csv"

# %%
# Twitter auth. https://dev.twitter.com/oauth/overview/application-owner-access-tokens

# with open("credentials.txt", "r") as f:
#     reader = csv.reader(f)
#     login_dict = {line[0]: line[1]                       
#                     for line in reader}        

api = twitter.Api(consumer_key='99mcVQZahMAqkGUbVDhQDmlMb' ,
                  consumer_secret='ubyuWD52HKUcEmaeJxdidS1jjb5w0PC26LJaI7SFhu4TLc78tC',
                  access_token_key='555800349-2zFuU4HDdr35k5aJPiCuWj3jO3oc50SDEEvOaZbD',
                  access_token_secret='DpR0oqFEAyD3bIk8G6LWy9jNQNMQhNj5eSv2rs2EiVabx')
api

# %%
print(twitter.__path__)
# Out:
# ['/Users/kuntojirohan/MCG/Twitter/twitter_graph/py36/lib/python3.6/site-packages/twitter']

# %%
# 'Self' and Friends of Self

self_node    =  api.GetUser(screen_name = self_screen_name)    
self_node_id =  str(self_node.id)                      # Twitter Id of Self
print(self_node_id)

friends_of_self = api.GetFriendIDs(user_id = self_node_id, 
                                   screen_name = self_screen_name , 
                                   stringify_ids = True)
index = [self_node_id] + friends_of_self
print(index)
# Out:
# 555800349
# ['555800349', '376825877', '70831441', '2785337469', '1076526138736951298', '1004265866739867648', '775449094739197953', '3018841323', '216939636', '20167623', '46245868', '62513246', '33838201', '991172011383803905', '80422885', '863720408', '2238652956', '534563976', '288100306', '8515852', '63873759', '254107028', '96951800', '627673190', '177547780', '15639696', '78941611', '29873662', '822215679726100480', '20536157', '57947109', '722214536460173312', '393033324', '303680301', '185142711', '1282946089', '15631238', '3138727082', '775302652427014145', '108252113', '19407053', '183230911', '54829997', '71201743', '8161232', '1636590253', '13298072', '44196397', '944427851280826368', '471745066', '872434564580294657', '1060849038', '937440997', '3007477369', '97865628', '18681139', '51376979', '101695592', '133880286', '101311381', '31678307', '14213195', '92724677', '135421739', '92708272', '18839785', '48410093', '155659213', '113419517', '145125358', '50393960', '88856792']

# %%
# GetFriendIDs() API call is rate-limited at 15 req / 15 min 
# https://dev.twitter.com/rest/public/rate-limiting

# For each of the list of nodes, fetch the list of nodes it follows, append to file

def update_FoF_File(fileName, to_fetch_list):
    
    with open(fileName, 'a') as f:
        apiReqCount = 0
        
        for node in to_fetch_list:
            friends_of_node = api.GetFriendIDs(user_id = node,  stringify_ids = True) 
            row = ','.join([str(i) for i in [node] +  friends_of_node ]) + "\n"
            f.write(row) 
            
            apiReqCount += 1
            
            if (apiReqCount == 15): 
                apiReqCount = 0
                
                print("Off to Sleep :)")
                time.sleep(15*60 + 10)

# %%
# parse FoF file and return list of nodes, for whom source->sink Edges are already there.

def getFinishList(fileName):
        
    if not os.path.isfile(fileName):
        return [] 
    with open(fileName, 'r') as f:
        return [ row.strip().split(',')[0] for row in f ]  # 1st entry is a user

# %%
# Ego-network as adjacency-matrix
# Parses FoF file in order of index, create list of adjacencies as 0 | 1
# Writes to File. Adjacency-matrix in Row_follows_Column format

def updateBinaryMapFile(fof_filename, binaryMap_filename, index):
    
    with open(fof_filename, "r") as f:
        stripped_f = (line.replace('\r', '') for line in f)
        reader = csv.reader(stripped_f)
        fof_dict = {line[0]: line[1:] for line in reader 
                    if line[0] in index}   # dict of node:his_followers
        if self_node_id not in fof_dict:
            fof_dict[self_node_id] = index[1:]             # dict of Self
    
    bool_list = []
    
    for user in index:
        user_friends = set( fof_dict[user] )  
        bool_row = [item in user_friends for item in index]  # for each, fill T/F 
        bool_list.append(bool_row)
    
    int_nparray = np.array(bool_list) + 0                    # Bool to int

    binaryMap_rfc = pd.DataFrame(data = int_nparray, columns= index, index = index)
    binaryMap_rfc.to_csv(binaryMap_filename)

# %%
# For list of Ids, fetch Profile details. If not in Offline file, make an API call
# Returns ['UserName', 'FullName', 'Followers_count', 'Friends_count', 'Location', 'Created_at']
# UsersLookup API 100 Ids/request

def lookup_in_cache(friendsIdsList):

    cache, delta_cache = pd.DataFrame(), pd.DataFrame()
    UserNameList, namesList     = [], []
    followers_count, friends_count = [], []
    location, created_at           = [], []
    
    if os.path.isfile(cache_filename):
        cache = pd.read_csv(cache_filename, skip_blank_lines=True,
                        dtype={'Ids':str, 'Friends_count':int, 'Followers_count':int})
        cache.set_index('Ids', inplace=True)
        to_fetch_list = list ( set (friendsIdsList) - set(cache.index) )
    else :        
        to_fetch_list = friendsIdsList   
    
    i = 0
    while (i < len(to_fetch_list) * 1./100):   
        print("... Cache-Miss for " + str(len(to_fetch_list)) +  " nodes. Updating Cache...")
        low, high = i * 100, min( len(to_fetch_list), (i+1)*100 )  # UsersLookup api
        twitterObjectsList = api.UsersLookup(user_id = to_fetch_list[low:high])    
        
        temp = zip(*[( tempObject.screen_name,        #ScreenName
                      tempObject.name,                #Name
                      tempObject.followers_count,     #Followers
                      tempObject.friends_count,       #Friends
                      tempObject.location,            #Location
                      tempObject.created_at           #CreatedAt
                     ) for tempObject in twitterObjectsList])
        temp = list(temp)
        
        UserNameList    += list(temp[0])
        namesList       += list(temp[1])
        followers_count += list(temp[2])
        friends_count   += list(temp[3])
        location        += list(temp[4])
        created_at      += list(temp[5])
        
        i = i + 1       
    
    if len(to_fetch_list) > 0:
        delta_cache  = pd.DataFrame({'UserName':UserNameList,
                                     'FullName':namesList,
                                     'Ids': to_fetch_list,
                                     'Followers':followers_count,
                                     'Friends': friends_count,
                                     'Location':location,
                                     'Created':created_at})
        
        delta_cache['Created'] = delta_cache['Created'].apply(lambda x: 
                                                datetime.strptime(
                                                    re.sub(r"\+[0-9]* ", "",x),'%c').
                                                strftime("%b-%Y"))
    
        delta_cache.set_index('Ids', inplace=True, drop = True)
        cache = cache.append(delta_cache)
        cache.to_csv(cache_filename)        

    return cache.loc[friendsIdsList]

# %%
# Display cluster-wise most-influential users, for the given clustering algo

def top_nodes_in_cluster(df, cluster_algo, n_clusters):
    dummy_df = pd.DataFrame()

    for i in range(n_clusters):
        nodes_in_cluster = list( df [df[cluster_algo] == i ]['FullName'] )     
        if len(nodes_in_cluster) >= 10:            # show only clusters of size > 10        
            col_name           = str(i) + " : " + str(len(nodes_in_cluster)) + " Ids"
            dummy_df[col_name] = nodes_in_cluster[:10]      
    
    return dummy_df

# %%
# identify 20 friends to follow after aggregating friends followed by top 50% in list

def discover_Friends_toFollow(ids_of_interest, friend_list, prop = .5, count = 20):    
    
    ids_of_interest  = ids_of_interest[:int(len(ids_of_interest) * prop)]
    
    if self_node_id in ids_of_interest:
        ids_of_interest.remove(self_node_id)

    print("'Who-To-Follow' reco after looking at %3d friends' friends:" %(len(ids_of_interest)))
    
    with open(fof_filename) as f:
        reader = csv.reader(f)
        fof_dict = {row[0]:row[0:] for row in reader}  # dict of node:her_followers

    friendsToFollow = []
    for id in ids_of_interest:
        friendsToFollow += list (set(fof_dict[str(id)])  - set(friend_list) ) 
        

    friendsToFollow = Counter(friendsToFollow).most_common(count)    
    tuples_list = list(zip(*friendsToFollow) )
           
    topFriendsToFollowDF = pd.DataFrame()
    topFriendsToFollowDF['Ids'] = list(tuples_list[0])
    topFriendsToFollowDF['Freq'] = list(tuples_list[1])
    topFriendsToFollowDF.set_index('Ids', drop = True, inplace = True)              
    index = topFriendsToFollowDF.index
    
    topFriendsToFollowDF = topFriendsToFollowDF.merge(lookup_in_cache(index), copy = False,
                              left_index = True, right_index = True)
    
    return topFriendsToFollowDF

# %%
# For the list of nodes I follow, fetch their friends-list

fof_finish_list   = getFinishList(fof_filename )        # Completed nodes
fof_to_fetch_list = list ( set(friends_of_self) - set(fof_finish_list) )  # Pending nodes

print( str(len(fof_to_fetch_list)) + " out of " + str(len(index)  - 1) + 
      " Friends details to be fetched")
# Out:
# 0 out of 71 Friends details to be fetched

# %%
# For the remaining nodes, populate their details in fof_file
update_FoF_File(fof_filename, fof_to_fetch_list) 

# Build the adjacency matrix in terms of 0 and 1 (if there is an edge)
updateBinaryMapFile(fof_filename, binaryMap_filename, index)

# %%
# Read adj-matrix into df. Cell MxN is 1 iff node in Mth row follows node in Nth column 
binaryMap_rfc = pd.read_csv(binaryMap_filename, skip_blank_lines=True, index_col = 0)
print(binaryMap_rfc.shape)


outlinks_count = binaryMap_rfc.sum(axis = 1)   # horizontal-sum to count outlinks
inlinks_count = binaryMap_rfc.sum(axis = 0)   # vertical-sum to count inlinks
# Out:
# (72, 72)

# %%
# Histogram of number of OutLinks per node, within ego-network
sns.distplot(outlinks_count, bins = len(index)//5, kde=False);

# %%
# Histogram of number of InLinks per node, within ego-network
sns.distplot(inlinks_count, bins = len(index)//5, kde=False);

# %% [markdown]
# ## 2. Identify influential friends using 'Page Rank' formulation

# %% [markdown]
# From the adjacency matrix generated above, we can construct a column-stochastic matrix  (also called a transition matrix) such that, a column with `m` outlinks will have `1/m` as value in respective `m` cells. Conceptually, a value in the cell `a x b` gives the probability of a random-surfer in node B jumping to node A.

# %%
binaryMap_cfr      = binaryMap_rfc.transpose()            # column-values: Outlinks
binaryMap_cfr_norm = binaryMap_cfr / binaryMap_cfr.sum(axis = 0)
colStochMatrix = np.matrix( binaryMap_cfr_norm.fillna(0)) # column-stochastic-matrix

# %% [markdown]
# _Initialize PageRank vector, such that all the nodes have equal PageRank score adding upto 1._

# %%
pageRankVector = np.matrix([1.0/len(index)] *  len(index)) # iniitialize page-rank-vector 
pageRankVector = pageRankVector.transpose()                # transpose to column-vector

# %% [markdown]
# On applying the above Transition-matrix transformation iteratively on the PageRank vector, the vector will eventully converge such that:
#
# `Matrix.Vector = Vector`
#
# Equivalently, this is Eigen-Vector formulation with PageRank vector being the principal eigen-vector of matrix corresponding to eigen-value `1` [Since M is column-stochastic matrix, principal eigen-value is 1]
#
# Here we use Power Iteration method to solve for the PageRank vector. Inorder to handle  the nodes which have zero out-links (dead-ends) and nodes with periodic-loops (spider-traps) in the ego-network, we introduce some randomness through parameter `beta` such that a random-surfer at any node picks a random path approx. every 1 out of 6 times ( 1 - beta = 0.15)

# %%
# PageRank algo: Power Iteration to solve Markov transition matrix 
# refer this     : http://setosa.io/blog/2014/07/26/markov-chains/index.html

beta = 0.85
epsilon = 999
iteration = 0
while epsilon > (1.0/(10**16)):
    pageRankVectorUpdating = colStochMatrix * pageRankVector * beta 
    
    # re-insert leaked page-ranks
    S = np.array(pageRankVectorUpdating).sum()                      
    pageRankVectorUpdated = pageRankVectorUpdating + (
        1 - S) * (1.0/len(index)) * np.ones_like(len(index))
    
    # compute the squared-difference and check for convergence
    error = np.array(pageRankVectorUpdated - pageRankVector)
    epsilon = np.sqrt((error *  error).sum())   
    iteration = iteration + 1
    pageRankVector = pageRankVectorUpdated    
    
print( "Sum of Page-Rank Scores: " + str(pageRankVector.sum()) + 
      "\nConverged in " + str(iteration) + " iterations")
# Out:
# Sum of Page-Rank Scores: 1.0
# Converged in 131 iterations

# %%
# Collect the results

results_df = pd.DataFrame()
results_df['Ids'], results_df['PageRank'] = index, pageRankVector
results_df['Inlinks'], results_df['Outlinks'] = list(inlinks_count), list(outlinks_count)
results_df = results_df.set_index('Ids', drop = True )

results_df = results_df.merge(lookup_in_cache(index), copy = False,
                              left_index = True, right_index = True)
results_df = results_df[['PageRank','UserName', 'FullName', 'Inlinks' , 'Outlinks',
                         'Followers','Friends', 'Location', 'Created' ]]
# Out:
# ... Cache-Miss for 72 nodes. Updating Cache...

# %%
results_df
# Out:
#                      PageRank         UserName             FullName  Inlinks  \
# Ids
# 555800349            0.004957     RohanKuntoji        Rohan Kuntoji        7
# 376825877            0.002929       TwitterOSS  Twitter Open Source        1
# 70831441             0.008212  soumithchintala     Soumith Chintala        6
# 2785337469           0.004203        seb_ruder      Sebastian Ruder        3
# 1076526138736951298  0.004427   paperswithcode     Papers with Code        3
# ...                       ...              ...                  ...      ...
# 155659213            0.013575        Cristiano    Cristiano Ronaldo        8
# 113419517            0.021098         iHrithik       Hrithik Roshan       19
# 145125358            0.040777       SrBachchan     Amitabh Bachchan       23
# 50393960             0.026798        BillGates           Bill Gates       20
# 88856792             0.016891       aamir_khan           Aamir Khan       16
#
#                      Outlinks  Followers  Friends         Location   Created
# Ids
# 555800349                  71         34       71    Mysore, India  Apr-2012
# 376825877                   0     322729       50       Twitter HQ  Sep-2011
# 70831441                    2      70874      318    New York City  Sep-2009
# 2785337469                 11      34573      751  London, England  Sep-2014
# 1076526138736951298         5      14671       44       London, UK  Dec-2018
# ...                       ...        ...      ...              ...       ...
# 155659213                   0   80217624       51  Turim, Piemonte  Jun-2010
# 113419517                   5   26437644       90                   Feb-2010
# 145125358                  32   38663364     1836    Mumbai, India  May-2010
# 50393960                    4   48153147      202      Seattle, WA  Jun-2009
# 88856792                    3   25156209        9           Mumbai  Nov-2009
#
# [72 rows x 9 columns]

# %% [markdown]
# #### 2a. Nodes with high PageRank scores

# %%
results_df.fillna('').sort_values(by = 'PageRank', ascending =False).set_index('FullName').head(10)
# Out:
#                   PageRank      UserName  Inlinks  Outlinks  Followers  \
# FullName
# TensorFlow        0.055500    TensorFlow       11         3     172811
# Google            0.051477        Google       12         2   21517665
# Google AI         0.047022      GoogleAI        8         2    1380565
# Amitabh Bachchan  0.040777    SrBachchan       23        32   38663364
# Tesla             0.037226         Tesla        5         2    4259108
# Sachin Tendulkar  0.036718     sachin_rt       26        10   30551511
# Elon Musk         0.035077      elonmusk       15         1   28473165
# Narendra Modi     0.032643  narendramodi       22         9   50489276
# Virat Kohli       0.027765      imVkohli       21         8   31654577
# Bill Gates        0.026798     BillGates       20         4   48153147
#
#                   Friends                 Location   Created
# FullName
# TensorFlow             96        Mountain View, CA  Feb-2011
# Google                214        Mountain View, CA  Feb-2009
# Google AI              14        Mountain View, CA  Apr-2009
# Amitabh Bachchan     1836            Mumbai, India  May-2010
# Tesla                  76                           Feb-2008
# Sachin Tendulkar       79  ÜT: 18.986431,72.823769  Apr-2010
# Elon Musk              81                           Jun-2009
# Narendra Modi        2266                    India  Jan-2009
# Virat Kohli            53                           Sep-2009
# Bill Gates            202              Seattle, WA  Jun-2009

# %%
results_df.FullName.unique()
# Out:
# array(['Rohan Kuntoji', 'Twitter Open Source', 'Soumith Chintala',
#        'Sebastian Ruder', 'Papers with Code', 'Mysuru Consulting Group',
#        'Ian Goodfellow', 'Open Data Science', 'Andrew Ng', 'KDnuggets',
#        'David Robinson', 'J.K. Rowling', 'Google AI', 'Sohan Kuntoji',
#        'Kaggle', 'Sunil Chhetri', 'Indian Football Team', 'Kirk Borne',
#        'Chinmay', 'Adam Geitgey', 'Python Software Foundation',
#        'TensorFlow', 'FC Barcelona', 'UEFA Champions League', 'ICC',
#        'IndianPremierLeague', 'Harsha Bhogle', 'Marques Brownlee',
#        'President Trump', 'Google', 'Flipkart', 'IBM Data Science & AI',
#        'Data Science Central', 'Ninad M G', 'BCCI', 'Amazon.in', 'Virgin',
#        'OnePlus India', 'Rakshak S | ರಕ್ಷಕ್ ಎಸ್', 'Vir Das',
#        'Entrepreneur', 'Alia Bhatt', 'Anushka Sharma', 'Virat Kohli',
#        'Richard Branson', 'Tim Cook', 'Tesla', 'Elon Musk',
#        'Soumak Chongder', 'Nikhil  P Huilgol', 'Ashika', 'Sandesh Hegde',
#        'Suhas Raju', 'Bindu smitha', 'Farhan Akhtar', 'PRIYANKA',
#        'Sonam K Ahuja', 'Deepika Padukone', 'Leonardo DiCaprio',
#        'Shah Rukh Khan', 'MSN Entertainment', 'MSN India',
#        'Virender Sehwag', 'Sachin Tendulkar', 'Mahendra Singh Dhoni',
#        'Narendra Modi', 'Tom Cruise', 'Cristiano Ronaldo',
#        'Hrithik Roshan', 'Amitabh Bachchan', 'Bill Gates', 'Aamir Khan'],
#       dtype=object)

# %% [markdown]
# #### 2b. Top 50 influential-nodes in Ego-Network

# %%
dummy_df = pd.DataFrame()
temp_df  = results_df.sort_values( by = 'PageRank', ascending =False)

for i in range(5):
    dummy_df[i] = pd.Series(list (temp_df [10*i : 10* i + 10]['FullName']))
dummy_df
# Out:
#                   0                     1                  2  \
# 0        TensorFlow             Andrew Ng         Aamir Khan
# 1            Google        Shah Rukh Khan      Farhan Akhtar
# 2         Google AI       Richard Branson           Tim Cook
# 3  Amitabh Bachchan  Mahendra Singh Dhoni     Ian Goodfellow
# 4             Tesla      Marques Brownlee     Anushka Sharma
# 5  Sachin Tendulkar        Hrithik Roshan   Deepika Padukone
# 6         Elon Musk     Leonardo DiCaprio  Cristiano Ronaldo
# 7     Narendra Modi       Virender Sehwag       J.K. Rowling
# 8       Virat Kohli              PRIYANKA             Kaggle
# 9        Bill Gates                  BCCI      Harsha Bhogle
#
#                        3                     4
# 0          Sonam K Ahuja      Soumith Chintala
# 1             Tom Cruise            Kirk Borne
# 2  UEFA Champions League  Data Science Central
# 3    IndianPremierLeague     Open Data Science
# 4              KDnuggets                Virgin
# 5        President Trump          Entrepreneur
# 6             Alia Bhatt               Vir Das
# 7   Indian Football Team                   ICC
# 8           FC Barcelona         Rohan Kuntoji
# 9          Sunil Chhetri          Adam Geitgey

# %% [markdown]
# #### 2c. Histogram of PageRank scores

# %% [markdown]
# PageRank scores are scaled such that nodes have an average-score of 1. So the scores below give an idea of how influential are the nodes, with respect to an average node.

# %%
pageRank_to_plot = len(index) * results_df["PageRank"]
sns.distplot(pageRank_to_plot, kde=False, rug=True, bins = len(index)//10);

# %% [markdown]
# A joint-plot showing how Inlinks and Outlinks of the nodes are distributed (within the ego-network)

# %%
sns.jointplot(x="Inlinks", y="Outlinks", data=results_df, kind = "kde");

# %% [markdown]
# ## 3. Identify implicit clusters using Clustering algos

# %% [markdown]
# Typically, number of clusters are chosen with a plot of within-cluster sum-of-squares-of-dstances vs number of clusters.
# Here for simplicity, we use a simple heuristic to fix the number of clusters in advnace.

# %%
n_clusters = min( int( round(np.sqrt(len(index)/2)) ), 10 ) # not more than 6 clusters
print(n_clusters)
# Out:
# 6

# %% [markdown]
# ## 3a. K-Means clustering

# %% [markdown]
# K Means is a point-assignment based clustering-algorithm: here we start with k points chosen randomly as centroids,  assign the remaining points to k centroids by using certain distance measure (Euclidean / Cosine / Jaccardi). Then we compute new centroids, re-assign remaining points and repeat, until there is convergence of centroids.
#
# Here we are more interested in clustering inherent in who-follows-me (network-driven) graph, rather than who-do-I-follow (self-driven). So the approach is to represent the nodes as Observations and whether other nodes follow them or not (1 or 0) as Features (One observation per row, and one feature per column) Thus the input matrix must be such that any value in cell implies whether node in the column follows node in the row.

# %%
from sklearn.cluster import KMeans
est = KMeans(max_iter = 100000, n_clusters = n_clusters, n_init = 200, init='k-means++')  
results_df['kmeans'] = est.fit_predict(binaryMap_cfr)

top_nodes_in_cluster(results_df.sort_values( by = 'PageRank', ascending =False), 
                     'kmeans', n_clusters)
# Out:
#               1 : 40 Ids         2 : 10 Ids            4 : 10 Ids
# 0                  Tesla     Shah Rukh Khan            TensorFlow
# 1        Richard Branson     Hrithik Roshan             Google AI
# 2       Marques Brownlee  Leonardo DiCaprio             Andrew Ng
# 3      Cristiano Ronaldo           PRIYANKA        Ian Goodfellow
# 4          Harsha Bhogle         Aamir Khan                Kaggle
# 5             Tom Cruise      Farhan Akhtar             KDnuggets
# 6  UEFA Champions League     Anushka Sharma      Soumith Chintala
# 7    IndianPremierLeague   Deepika Padukone            Kirk Borne
# 8        President Trump      Sonam K Ahuja  Data Science Central
# 9   Indian Football Team         Alia Bhatt     Open Data Science

# %% [markdown]
# ## 3b. Spectral clustering

# %% [markdown]
# One problem in using K-Means algorithm to cluster the given social-graph is 'Curse of Dimensionality' i.e. at higher-dimensions (here ~400 dimensions), metric like 'Euclidean distance' or 'Centre' would have little meaning in the context of non-convex adjacency matrix.
#
# On the other hand, spectral clustering attempts to partition the graph such that number of edges which connect different components are minimized. Below is the output from Spectral Clustering.

# %%
from sklearn import cluster

spectral = cluster.SpectralClustering(n_clusters=n_clusters,  n_init = 500,
                                          eigen_solver='arpack',
                                          affinity="nearest_neighbors")
spectral.fit(binaryMap_cfr)
results_df['spectral'] = spectral.labels_.astype(np.int)

top_nodes_in_cluster(results_df.sort_values( by = 'PageRank', ascending =False), 
                     'spectral', n_clusters)
# Out:
# /Users/kuntojirohan/MCG/Twitter/twitter_graph/py36/lib/python3.6/site-packages/sklearn/cluster/spectral.py:462: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn("The spectral clustering API has changed. ``fit``"
#               0 : 14 Ids             1 : 23 Ids            2 : 12 Ids
# 0   Mahendra Singh Dhoni              Google AI            TensorFlow
# 1       Marques Brownlee        Richard Branson             Andrew Ng
# 2      Cristiano Ronaldo             Tom Cruise        Ian Goodfellow
# 3          Harsha Bhogle           FC Barcelona                Kaggle
# 4  UEFA Champions League                 Virgin             KDnuggets
# 5    IndianPremierLeague           Entrepreneur      Soumith Chintala
# 6   Indian Football Team          Rohan Kuntoji            Kirk Borne
# 7          Sunil Chhetri       Papers with Code  Data Science Central
# 8                Vir Das  IBM Data Science & AI     Open Data Science
# 9                    ICC             Suhas Raju          Adam Geitgey

# %% [markdown]
# Nodes mainly into Deep Learning community have grouped into Cluster 8, Python Machine Learning community into Cluster 2, Design community into Cluster 9, general Data Science community into Cluster 0 and 5

# %% [markdown]
# One smaller clusters (1) wasn't shown above.

# %%
results_df [results_df['spectral'].isin([1])].sort_values(by = 'PageRank', ascending =False).set_index('FullName').head()
# Out:
#                  PageRank        UserName  Inlinks  Outlinks  Followers  \
# FullName
# Google AI        0.047022        GoogleAI        8         2    1380565
# Richard Branson  0.024579  richardbranson        6         7   12664546
# Tom Cruise       0.012091       TomCruise        3         9    6740721
# FC Barcelona     0.009043     FCBarcelona        3         1   30930757
# Entrepreneur     0.005913    Entrepreneur        2         4    3463102
#
#                  Friends           Location   Created  kmeans  spectral
# FullName
# Google AI             14  Mountain View, CA  Apr-2009       4         1
# Richard Branson     3893                     Aug-2007       1         1
# Tom Cruise         53409          Worldwide  Jun-2009       1         1
# FC Barcelona          79          Barcelona  Dec-2009       1         1
# Entrepreneur        1454         Irvine, CA  Jan-2009       1         1

# %% [markdown]
# ## 3c. Affinity Propagation clustering

# %% [markdown]
# Unlike K-Means or Spectral clustering, affinity propagation doesn't require the number of clusters to be estimated beforehand. Here the algorithm finds 'exemplars' i.e. members of dataset that are representative of clusters. and tries to find clusters around them.

# %%
from sklearn.cluster import AffinityPropagation

af = AffinityPropagation(preference=-50).fit(binaryMap_cfr)
results_df['affinity'] = af.labels_
n_clusters_affinity = len(af.cluster_centers_indices_)

print(str(n_clusters_affinity) + " affinity clusters.")

top_nodes_in_cluster(results_df.sort_values( by = 'PageRank', ascending =False), 
                     'affinity', n_clusters_affinity)
# Out:
# 2 affinity clusters.
#              0 : 61 Ids        1 : 11 Ids
# 0            TensorFlow  Amitabh Bachchan
# 1                Google  Sachin Tendulkar
# 2             Google AI     Narendra Modi
# 3                 Tesla       Virat Kohli
# 4             Elon Musk    Shah Rukh Khan
# 5            Bill Gates    Hrithik Roshan
# 6             Andrew Ng   Virender Sehwag
# 7       Richard Branson          PRIYANKA
# 8  Mahendra Singh Dhoni        Aamir Khan
# 9      Marques Brownlee     Farhan Akhtar

# %% [markdown]
# ## 3d. Principal Component Analysis

# %% [markdown]
# To handle the 'curse of dimensionality' problem inherent in high-dimension data, PCA is generally used to represent the high-dimensional data in a fewer number of dimensions - this helps in better visualizing of data as well as faster computation while running clustering algorithm.

# %%
pca = PCA(n_components=3)
Xproj = pca.fit_transform(binaryMap_cfr)

results_df['dim1'] = Xproj[:,0]
results_df['dim2'] = Xproj[:,1]
results_df['dim3'] = Xproj[:,2]

results_df = results_df.sort_values( by = 'PageRank', ascending =False)
results_df.to_csv(cluster_filename)

print("Explained-variance and Proportion of Explained-variance in 3 dimensions [dim1 dim2 dim3]")
print(pca.explained_variance_, pca.explained_variance_ratio_)
# Out:
# Explained-variance and Proportion of Explained-variance in 3 dimensions [dim1 dim2 dim3]
# [1.61749939 0.48646669 0.41671062] [0.2902709  0.08729965 0.07478146]

# %% [markdown]
# A simpler visualization of Spectral-clustering outcome as rendered in 2 dimensions.

# %%
# Spectral clustering | Plot the ego-network in 2 dimensions

plt.figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')
plt.scatter(results_df['dim1'], results_df['dim2'], s = 100  ,c= results_df['spectral'], 
            alpha=0.5, cmap=plt.cm.get_cmap('nipy_spectral', 10))
plt.colorbar();

# %% [markdown]
# More on Clustering Algorithms:  http://scikit-learn.org/stable/modules/clustering.html

# %% [markdown]
# ## 4. Recommend new friends to follow

# %% [markdown]
# Now that we have PageRank in place for nodes in social-graph, we can ask for recommendations on the basis of top-ranked nodes in the graph. E.g. To get 20 recommendations, after looking at friends of top PageRank scoring nodes in my network

# %% [markdown]
# #### 4a. Reco: After looking at top nodes in full ego-network

# %%
discover_Friends_toFollow(ids_of_interest = index,
                          friend_list = friends_of_self, 
                          prop = .5 , count =  20).fillna('').set_index('FullName')
# Out:
# 'Who-To-Follow' reco after looking at  35 friends' friends:
# ... Cache-Miss for 20 nodes. Updating Cache...
#                     Freq         UserName  Followers  Friends  \
# FullName
# Yann LeCun            11           ylecun     157351      231
# Andrej Karpathy       10         karpathy     231814      507
# Andreas Mueller        9       amuellerml      35869      894
# DeepMind               9       DeepMindAI     258765      115
# Stanford NLP Group     9      stanfordnlp      81113      100
# François Chollet       9         fchollet     162588      595
# Fei-Fei Li             9         drfeifei     324869      264
# Hugo Larochelle        8  hugo_larochelle      72871      494
# Jeff Dean              8         JeffDean     118243     2156
# Jeremy Howard          8    jeremyphoward      69888     1286
# Chris Olah             8            ch402      47210      172
# Sundar Pichai          8     sundarpichai    2483187      336
# Moritz Hardt           7             mrtz       8854      327
# Pete Warden            7       petewarden      18345     2014
# Oriol Vinyals          7   OriolVinyalsML      77859       48
# Ryan Adams             7     ryan_p_adams      26299      872
# Hilary Mason           7           hmason     118024     1654
# Monica Rogati          7          mrogati      48357      566
# Gautam Gambhir         7    GautamGambhir    9938638      121
# Suresh Raina🇮🇳         7          ImRaina   16857878      300
#
#                                 Location   Created
# FullName
# Yann LeCun                      New York  Jun-2009
# Andrej Karpathy                 Stanford  Apr-2009
# Andreas Mueller                      NYC  Jan-2012
# DeepMind                      London, UK  Jan-2016
# Stanford NLP Group     Stanford, CA, USA  Feb-2010
# François Chollet       Mountain View, CA  Aug-2009
# Fei-Fei Li          Stanford, CA, U.S.A.  Apr-2010
# Hugo Larochelle                           Jun-2015
# Jeff Dean                                 Sep-2017
# Jeremy Howard              San Francisco  Aug-2010
# Chris Olah             San Francisco, CA  Jun-2010
# Sundar Pichai                             Mar-2008
# Moritz Hardt                Berkeley, CA  Aug-2008
# Pete Warden            San Francisco, CA  May-2008
# Oriol Vinyals            London, England  Oct-2015
# Ryan Adams                                Jan-2015
# Hilary Mason                         NYC  Feb-2007
# Monica Rogati              Sunnyvale, CA  Nov-2008
# Gautam Gambhir                            Dec-2009
# Suresh Raina🇮🇳                     India  Mar-2010

# %% [markdown]
# Recommendations on the basis of a specific cluster outcome.
# E.g. Nodes to follow on the basis of top PageRank nodes in 'Spectral Clustering::Data' clusters.

# %% [markdown]
# #### Reco: 4b. After looking at Research (AI) community clustser (Spectral clustering)

# %%
favorite_cluster_df = results_df [results_df['spectral'].isin([2])]
favorite_cluster_list = list(favorite_cluster_df.index)

discover_Friends_toFollow(ids_of_interest = favorite_cluster_list, 
                          friend_list = friends_of_self, 
                          prop = .5, count = 30).fillna('').set_index('FullName')
# Out:
# 'Who-To-Follow' reco after looking at   6 friends' friends:
#                                         Freq         UserName  Followers  \
# FullName
# Yann LeCun                                 6           ylecun     157351
# Hugo Larochelle                            5  hugo_larochelle      72871
# Jeff Dean                                  5         JeffDean     118243
# Chris Olah                                 5            ch402      47210
# DeepMind                                   5       DeepMindAI     258765
# François Chollet                           5         fchollet     162588
# Jeremy Howard                              5    jeremyphoward      69888
# Andrej Karpathy                            5         karpathy     231814
# Oriol Vinyals                              4   OriolVinyalsML      77859
# distillpub                                 4       distillpub      27915
# Douglas Eck                                4      douglas_eck       8344
# Ryan Adams                                 4     ryan_p_adams      26299
# Stanford NLP Group                         4      stanfordnlp      81113
# Moritz Hardt                               4             mrtz       8854
# Pete Warden                                4       petewarden      18345
# Anthony Goldbloom                          4     antgoldbloom      35042
# mat kelcey                                 3       mat_kelcey       6646
# Derek Murray                               3             mrry       3643
# Taehoon Kim                                3        carpedm20       2540
# Melody Guan ʕᵔᴥᵔʔ                          3       MelodyGuan       3117
# Sundar Pichai                              3     sundarpichai    2483187
# Luke Metz                                  3        Luke_Metz       4026
# Jasper                                     3     latentjasper       4198
# Denny Britz                                3       dennybritz      39745
# 👩‍💻 DynamicWebPaige @ #TFDocsSprint ✍️     3  DynamicWebPaige      30519
# Dumitru Erhan                              3           doomie       4806
# hardmaru                                   3         hardmaru      64655
# Rajat Monga                                3       rajatmonga      13248
# Eric Jang                                  3       ericjang11      14398
# a16z                                       3             a16z     346731
#
#                                         Friends  \
# FullName
# Yann LeCun                                  231
# Hugo Larochelle                             494
# Jeff Dean                                  2156
# Chris Olah                                  172
# DeepMind                                    115
# François Chollet                            595
# Jeremy Howard                              1286
# Andrej Karpathy                             507
# Oriol Vinyals                                48
# distillpub                                   81
# Douglas Eck                                 631
# Ryan Adams                                  872
# Stanford NLP Group                          100
# Moritz Hardt                                327
# Pete Warden                                2014
# Anthony Goldbloom                           575
# mat kelcey                                 1071
# Derek Murray                                345
# Taehoon Kim                                 592
# Melody Guan ʕᵔᴥᵔʔ                           699
# Sundar Pichai                               336
# Luke Metz                                   992
# Jasper                                      250
# Denny Britz                                 380
# 👩‍💻 DynamicWebPaige @ #TFDocsSprint ✍️     1205
# Dumitru Erhan                              1070
# hardmaru                                    657
# Rajat Monga                                 214
# Eric Jang                                  1434
# a16z                                         22
#
#                                                                                  Location  \
# FullName
# Yann LeCun                                                                       New York
# Hugo Larochelle
# Jeff Dean
# Chris Olah                                                              San Francisco, CA
# DeepMind                                                                       London, UK
# François Chollet                                                        Mountain View, CA
# Jeremy Howard                                                               San Francisco
# Andrej Karpathy                                                                  Stanford
# Oriol Vinyals                                                             London, England
# distillpub
# Douglas Eck                                                             Mountain View, CA
# Ryan Adams
# Stanford NLP Group                                                      Stanford, CA, USA
# Moritz Hardt                                                                 Berkeley, CA
# Pete Warden                                                             San Francisco, CA
# Anthony Goldbloom                                                           San Francisco
# mat kelcey                                                            Victoria, Australia
# Derek Murray                                                            San Francisco, CA
# Taehoon Kim                                                             San Francisco, CA
# Melody Guan ʕᵔᴥᵔʔ                                                            Stanford, CA
# Sundar Pichai
# Luke Metz                                                               Mountain View, CA
# Jasper
# Denny Britz
# 👩‍💻 DynamicWebPaige @ #TFDocsSprint ✍️                     179°56′39.4″, +0°2′46.2″ 8k pc
# Dumitru Erhan                                                           San Francisco, CA
# hardmaru                                                                               東京
# Rajat Monga
# Eric Jang
# a16z                                    Andreessen Horowitz is a tech VC firm based in...
#
#                                          Created
# FullName
# Yann LeCun                              Jun-2009
# Hugo Larochelle                         Jun-2015
# Jeff Dean                               Sep-2017
# Chris Olah                              Jun-2010
# DeepMind                                Jan-2016
# François Chollet                        Aug-2009
# Jeremy Howard                           Aug-2010
# Andrej Karpathy                         Apr-2009
# Oriol Vinyals                           Oct-2015
# distillpub                              Oct-2016
# Douglas Eck                             Aug-2010
# Ryan Adams                              Jan-2015
# Stanford NLP Group                      Feb-2010
# Moritz Hardt                            Aug-2008
# Pete Warden                             May-2008
# Anthony Goldbloom                       Jul-2010
# mat kelcey                              Mar-2009
# Derek Murray                            Feb-2007
# Taehoon Kim                             Jan-2011
# Melody Guan ʕᵔᴥᵔʔ                       Apr-2011
# Sundar Pichai                           Mar-2008
# Luke Metz                               Oct-2012
# Jasper                                  Apr-2009
# Denny Britz                             Jan-2008
# 👩‍💻 DynamicWebPaige @ #TFDocsSprint ✍️  Dec-2008
# Dumitru Erhan                           Apr-2008
# hardmaru                                Nov-2014
# Rajat Monga                             Nov-2008
# Eric Jang                               Jan-2014
# a16z                                    Aug-2009

# %% [markdown]
# #### Reco: 4c. After looking at Bollywood actors clustser (Spectral clustering)

# %%
favorite_cluster_df = results_df [results_df['spectral'].isin([5])]
favorite_cluster_list = list(favorite_cluster_df.index)

discover_Friends_toFollow(ids_of_interest = favorite_cluster_list, 
                          friend_list = friends_of_self, 
                          prop = .5, count = 30).fillna('').set_index('FullName')
# Out:
# 'Who-To-Follow' reco after looking at   4 friends' friends:
#                       Freq         UserName  Followers  Friends  \
# FullName
# Chulbul Pandey           3  BeingSalmanKhan   38222008       24
# Abhishek Bachchan        3   juniorbachchan   14707884      410
# Karan Johar              3       karanjohar   16664147      485
# Barack Obama             3      BarackObama  108917081   611754
# Preity G Zinta           2  realpreityzinta    4806691      105
# Dia Mirza                2         deespeak    3056203     1075
# Anil Kapoor              2       AnilKapoor    4994313       60
# Ranveer Singh            2  RanveerOfficial   12789980      862
# Bubbles                  2      bubblesbehl       7358       59
# Kunal Kapoor             2     kapoorkkunal     573211       56
# Komal Nahta              2       KomalNahta     986506       33
# Farah Khan               2     FarahKhanAli     686631      977
# Shekhar Kapur            2     shekharkapur    2736502      502
# Vineet jain              2  vineetjaintimes     130299      194
# Shahid Kapoor            2     shahidkapoor   14494052       96
# Sussanne Khan            2  sussannekroshan     610088       71
# Ritesh Sidhwani          2       ritesh_sid     575560      120
# Rishi Kapoor             2        chintskap    3354356       27
# Twitterrific             2     Twitterrific     409492       15
# Anupam Kher              2      AnupamPKher   14268202      175
# Raj Nayak                2     rajcheerfull     566978      741
# Uday Chopra              2       udaychopra    1481809      379
# goldie behl              2       GOLDIEBEHL     134402      666
# Sonali Bendre Behl       2  iamsonalibendre     321123      129
# Jacqueline Fernandez     2  Asli_Jacqueline   14051330      202
# King Mika Singh          2        MikaSingh    4207945      173
# Dino Morea               2       DinoMorea9     534421      287
# DABBOO RATNANI           2    DabbooRatnani    1736573      583
# Azmi Shabana             2      AzmiShabana    3270467      271
# Afsar Zaidi              2       afsarzaidi      22632      137
#
#                                       Location   Created
# FullName
# Chulbul Pandey                          MUMBAI  Apr-2010
# Abhishek Bachchan                Mumbai, India  Nov-2009
# Karan Johar                 Maharashtra, India  Jul-2009
# Barack Obama                    Washington, DC  Mar-2007
# Preity G Zinta         Catch me if you can....  Oct-2009
# Dia Mirza                                India  Feb-2010
# Anil Kapoor                      Mumbai, India  Aug-2013
# Ranveer Singh                           Mumbai  Aug-2009
# Bubbles                                         Mar-2016
# Kunal Kapoor                            mumbai  Jan-2010
# Komal Nahta                             Bombay  Feb-2010
# Farah Khan             ÜT: 19.110207,72.825719  Aug-2009
# Shekhar Kapur                           Mumbai  Jun-2008
# Vineet jain                             mumbai  Jan-2013
# Shahid Kapoor                                   Jul-2009
# Sussanne Khan          ÜT: 19.109427,72.825723  Feb-2010
# Ritesh Sidhwani                   Mumbai-India  Oct-2011
# Rishi Kapoor              Home, Mumbai, India   Jan-2010
# Twitterrific             a tree in Dubuque, IA  Jan-2007
# Anupam Kher                      Mumbai, India  Sep-2009
# Raj Nayak                                Earth  Oct-2009
# Uday Chopra           Hell, 7th Fire, Oven 666  Jul-2009
# goldie behl                         right here  Jun-2009
# Sonali Bendre Behl                              Oct-2015
# Jacqueline Fernandez                            Oct-2009
# King Mika Singh                         mumbai  Jun-2012
# Dino Morea                 Mumbai, Maharashtra  Jul-2009
# DABBOO RATNANI                   Mumbai, India  Jun-2009
# Azmi Shabana           ÜT: 19.111431,72.823609  Mar-2010
# Afsar Zaidi                                     Jul-2009

# %% [markdown]
# #### 4d.Reco:  After looking at Sports clustser (Spectral clustering)

# %%
favorite_cluster_df = results_df [results_df['spectral'].isin([0])]
favorite_cluster_list = list(favorite_cluster_df.index)

discover_Friends_toFollow(ids_of_interest = favorite_cluster_list, 
                          friend_list = friends_of_self, 
                          prop = .5, count = 30).fillna('').set_index('FullName')
# Out:
# 'Who-To-Follow' reco after looking at   7 friends' friends:
#                              Freq         UserName  Followers  Friends  \
# FullName
# Ashwin Ravichandran             3     ashwinravi99    9698651      236
# Gautam Gambhir                  3    GautamGambhir    9938638      121
# Suresh Raina🇮🇳                  3          ImRaina   16857878      300
# Twitter Sports                  3    TwitterSports   15272596     1992
# Ishant Sharma                   2         ImIshant    2264007       60
# Rohit Sharma                    2           ImRo45   14930299       43
# R P Singh रुद्र प्रताप सिंह     2          rpsingh    1574542      322
# Amit Mishra                     2        MishiAmit    1354021       54
# Prannoy Roy                     2   PrannoyRoyNDTV     758697      487
# Chennaiyin FC 🏆🏆                2     ChennaiyinFC     861166       98
# zaheer khan                     2         ImZaheer    5944164      204
# Anirudh Chaudhry                2  AnirudhChaudhry     287886      332
# Manchester United               2           ManUtd   20283139      129
# Harbhajan Turbanator            2  harbhajan_singh   10189709      128
# yuvraj singh                    2      YUVSTRONG12    4720718      378
# Sundar Pichai                   2     sundarpichai    2483187      336
# Kobe Bryant                     2       kobebryant   14499233      509
# Rio Ferdinand                   2        rioferdy5   10554871      613
# JuventusFC                      2       juventusfc    7341905       57
# Álvaro Arbeloa                  2       aarbeloa17    6049324     1236
# Xabi Alonso                     2       XabiAlonso   11930664      536
# Kaka                            2             KAKA   29667500      305
# James Rodríguez                 2  jamesdrodriguez   18439360      295
# Instagram                       2        instagram   36380296       62
# Nani                            2         luisnani    3925469      176
# Pepe                            2     officialpepe    3564452       42
# Radamel Falcao                  2           FALCAO   17433711      619
# Dwayne DJ Bravo                 2        DJBravo47    1038819        0
# Michael Clarke                  2        MClarke23    2144133      629
# Ajinkya Rahane                  2  ajinkyarahane88    5594361       69
#
#                                                 Location   Created
# FullName
# Ashwin Ravichandran                              Chennai  Aug-2011
# Gautam Gambhir                                            Dec-2009
# Suresh Raina🇮🇳                                     India  Mar-2010
# Twitter Sports                                            May-2011
# Ishant Sharma                           New Delhi, India  Dec-2009
# Rohit Sharma                                              Mar-2010
# R P Singh रुद्र प्रताप सिंह            Rae bareli, India  Feb-2010
# Amit Mishra                                        Delhi  Apr-2010
# Prannoy Roy                                        India  Oct-2009
# Chennaiyin FC 🏆🏆                                 Chennai  Sep-2014
# zaheer khan                                               Jan-2010
# Anirudh Chaudhry                                          Mar-2010
# Manchester United                    Manchester, England  Apr-2012
# Harbhajan Turbanator                               India  Nov-2009
# yuvraj singh                               Mumbai, India  Jul-2009
# Sundar Pichai                                             Mar-2008
# Kobe Bryant                                               Jan-2013
# Rio Ferdinand                 www.neweraglobalsports.com  Jun-2010
# JuventusFC                               Allianz Stadium  Feb-2011
# Álvaro Arbeloa               Madrid, Comunidad de Madrid  Apr-2009
# Xabi Alonso                                               Aug-2010
# Kaka                                                      Jul-2009
# James Rodríguez              Madrid, Comunidad de Madrid  Apr-2011
# Instagram                                                 Aug-2010
# Nani                                                      Feb-2011
# Pepe                                                      Jul-2011
# Radamel Falcao                         Estambul, Turquía  Jul-2009
# Dwayne DJ Bravo                                           Sep-2010
# Michael Clarke                   Sydney, New South Wales  Nov-2009
# Ajinkya Rahane                                    Mumbai  Aug-2011

# %% [markdown]
# #### Reco: 4e. After looking at Tech & Media community clustser (Spectral clustering)

# %%
favorite_cluster_df = results_df [results_df['spectral'].isin([4])]
favorite_cluster_list = list(favorite_cluster_df.index)

discover_Friends_toFollow(ids_of_interest = favorite_cluster_list, 
                          friend_list = friends_of_self, 
                          prop = .5, count = 30).fillna('').set_index('FullName')
# Out:
# 'Who-To-Follow' reco after looking at   3 friends' friends:
#                        Freq         UserName  Followers  Friends  \
# FullName
# New Scientist             3     newscientist    3528447      145
# Slashdot                  2         slashdot     241209      147
# Ars Technica              2      arstechnica    1168522     1233
# GigaOm                    2           gigaom     309985     1155
# Gizmodo                   2          Gizmodo    2892136      139
# TechCrunch                2       TechCrunch   10104486     1050
# NASA                      2             NASA   33248641      298
# Techmeme                  2         Techmeme     399577      921
# The Onion                 2         TheOnion   11320535       15
# TeslaRoadTrip             2    TeslaRoadTrip      57198       69
# Neil deGrasse Tyson       2        neiltyson   13475967       39
# CleanTechnica             2    cleantechnica     104221      141
# bill lee                  2    westcoastbill      39946      549
# SpaceX                    2           SpaceX    9051744      107
# Rick and Morty            2     RickandMorty    1746681      201
# Hyperloop                 2        Hyperloop     180224       95
# Tim Urban                 2       waitbutwhy     208761      578
# OpenAI                    2           OpenAI     379085        0
# The Boring Company        2    boringcompany     327424        5
# TESLARATI                 2        Teslarati     127849       71
# Backchannel               1        backchnnl      24365      294
# Google Nest               1       googlenest     195530       12
# Google Australia NZ       1  googledownunder      72566      622
# Google Communications     1     Google_Comms      34452      373
# Matías Duarte             1     MatiasDuarte      32226      391
# Google for Nonprofits     1  googlenonprofit      20952      296
# Google.org                1        Googleorg      66519      320
# BI Tech                   1              SAI    1284518       67
# Eric Schmidt              1      ericschmidt    2311883      187
# Google Россия             1     GoogleRussia    2088130       90
#
#                                           Location   Created
# FullName
# New Scientist                            Worldwide  Jan-2009
# Slashdot                             San Francisco  Mar-2007
# Ars Technica           NYC - Boston - Chicago - SF  Jan-2007
# GigaOm                                  Austin, TX  Mar-2007
# Gizmodo                                             Mar-2007
# TechCrunch                       San Francisco, CA  Mar-2007
# NASA                                                Dec-2007
# Techmeme                             United States  Mar-2007
# The Onion                                           Mar-2008
# TeslaRoadTrip                        United States  Feb-2013
# Neil deGrasse Tyson                  New York City  Jan-2009
# CleanTechnica                                       Oct-2008
# bill lee                               Being First  Jan-2007
# SpaceX                               Hawthorne, CA  Apr-2009
# Rick and Morty                                      Jul-2012
# Hyperloop                            Hawthorne, CA  Aug-2013
# Tim Urban                                           Mar-2013
# OpenAI                                              Dec-2015
# The Boring Company                 Los Angeles, CA  May-2017
# TESLARATI                               California  Mar-2013
# Backchannel                      San Francisco, CA  Oct-2014
# Google Nest                                   Home  Jul-2010
# Google Australia NZ                         Sydney  Apr-2009
# Google Communications            Mountain View, CA  Sep-2017
# Matías Duarte                                       May-2009
# Google for Nonprofits                               Feb-2011
# Google.org                       Mountain View, CA  May-2014
# BI Tech                               New York, NY  Sep-2007
# Eric Schmidt                     Mountain View, CA  Dec-2009
# Google Россия                                       Jul-2009

# %%
discover_Friends_toFollow(ids_of_interest = list(results_df [results_df['spectral'] == 5].index), 
                          friend_list = friends_of_self, 
                          prop = 1, count = 20).fillna('').set_index('FullName')
# Out:
# 'Who-To-Follow' reco after looking at   9 friends' friends:
# ... Cache-Miss for 4 nodes. Updating Cache...
#                       Freq         UserName  Followers  Friends  \
# FullName
# Karan Johar              8       karanjohar   16664147      485
# Ranveer Singh            7  RanveerOfficial   12789980      862
# Shahid Kapoor            7     shahidkapoor   14494052       96
# Abhishek Bachchan        7   juniorbachchan   14707884      410
# Chulbul Pandey           6  BeingSalmanKhan   38222008       24
# Barack Obama             6      BarackObama  108917081   611754
# taran adarsh             6     taran_adarsh    3680564      179
# Arjun Kapoor             6         arjunk26    6128252      794
# J                        6    jiteshpillaai     721109     1170
# Dia Mirza                5         deespeak    3056203     1075
# Twinkle Khanna           5    mrsfunnybones    5316236       88
# Rishi Kapoor             5        chintskap    3354356       27
# Uday Chopra              5       udaychopra    1481809      379
# Jacqueline Fernandez     5  Asli_Jacqueline   14051330      202
# Azmi Shabana             5      AzmiShabana    3270467      271
# Ronnie Screwvala         5  RonnieScrewvala    2130370      293
# barkha dutt              5            BDUTT    6975662     2191
# Priya Gupta              5    priyagupta999     643397      535
# MissMalini               5       MissMalini    2757942     4222
# Farah Khan               5     TheFarahKhan    6738536       74
#
#                                       Location   Created
# FullName
# Karan Johar                 Maharashtra, India  Jul-2009
# Ranveer Singh                           Mumbai  Aug-2009
# Shahid Kapoor                                   Jul-2009
# Abhishek Bachchan                Mumbai, India  Nov-2009
# Chulbul Pandey                          MUMBAI  Apr-2010
# Barack Obama                    Washington, DC  Mar-2007
# taran adarsh                     Mumbai, India  Dec-2009
# Arjun Kapoor                                    Apr-2014
# J                                       Mumbai  May-2009
# Dia Mirza                                India  Feb-2010
# Twinkle Khanna                                  Aug-2014
# Rishi Kapoor              Home, Mumbai, India   Jan-2010
# Uday Chopra           Hell, 7th Fire, Oven 666  Jul-2009
# Jacqueline Fernandez                            Oct-2009
# Azmi Shabana           ÜT: 19.111431,72.823609  Mar-2010
# Ronnie Screwvala                        Mumbai  May-2012
# barkha dutt                              India  Feb-2009
# Priya Gupta                             Mumbai  Jun-2012
# MissMalini                              Bombay  Oct-2008
# Farah Khan                       Mumbai, India  Sep-2010
